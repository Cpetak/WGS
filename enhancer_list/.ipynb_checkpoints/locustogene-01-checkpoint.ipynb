# %%
import pandas as pd
from collections import Counter
from matplotlib import pyplot
import numpy as np

# %%
df = pd.read_csv('all_annotations.txt', sep="\t", header=None, names=["chr","source","type","start","stop","s1","s2","s3","info"])

# %%
df.drop(df[df['type'] == "region"].index, inplace = True)

# %%
df.type.unique()
# Out:
# array(['gene', 'mRNA', 'exon', 'CDS', 'snRNA', 'pseudogene', 'cDNA_match',
#        'tRNA', 'lnc_RNA', 'transcript', 'snoRNA', 'rRNA',
#        'primary_transcript', 'miRNA', 'sequence_feature', 'tandem_repeat',
#        'promoter'], dtype=object)

# %%
df['info'] = df['info'].str.replace(',',';')

# %%
df.s2.unique()
# Out:
# array(['+', '-'], dtype=object)

# %%
loci = pd.read_csv('top_goodhe_01', header=None, names=["chr","fst"])

# %%
loci
# Out:
#                           chr     fst
# 0       NW_022145599.1_809765  0.2058
# 1     NW_022145613.1_22684111  0.1950
# 2     NW_022145600.1_36849648  0.1883
# 3     NW_022145612.1_13121687  0.1882
# 4     NW_022145595.1_20882520  0.1873
# ...                       ...     ...
# 6842  NW_022145597.1_27269202  0.1000
# 6843  NW_022145597.1_25996126  0.1000
# 6844  NW_022145596.1_12214610  0.1000
# 6845   NW_022145595.1_3170334  0.1000
# 6846  NW_022145595.1_16380245  0.1000
#
# [6847 rows x 2 columns]

# %%
# if just looking at also high bayenv

# %%
hbay = pd.read_csv('high_bayenv.csv', header=None, sep='\t',names=["index","ave","chr","fst","pos","ch_num","idx","log_bf"])

# %%
hbay["comb"]=hbay["chr"] +"_"+ hbay["pos"]

# %%
hbay
# Out:
#      index                 ave             chr     fst       pos  ch_num  \
# 0    index                 ave             chr     fst       pos  ch_num
# 1     6804   9.470158600000001  NW_022145612.1     0.1    757345       1
# 2     6818             2.86165  NW_022145611.1     0.1  36506506       2
# 3     6840  1.2448080000000001  NW_022145599.1     0.1  23380763       7
# 4     6769            1.686525  NW_022145601.1  0.1001  22443666      12
# ..     ...                 ...             ...     ...       ...     ...
# 249    100            1.213802  NW_022145603.1  0.1553  26343419      17
# 250     96  1.3058999999999998  NW_022145599.1  0.1562  23070922       7
# 251     32   46.59352199999999  NW_022145615.1  0.1668  25383710       4
# 252     17  1.4565804000000002  NW_022145598.1  0.1732    416271      16
# 253      1            1.036662  NW_022145613.1   0.195  22684111       3
#
#       idx                log_bf                     comb
# ...

# %%
loci=hbay[["comb","fst"]].copy()

# %%
loci=loci.drop(loci.index[0])

# %%
loci["chr"]=loci["comb"]

# %%
loci
# Out:
#                         comb     fst                      chr
# 1      NW_022145612.1_757345     0.1    NW_022145612.1_757345
# 2    NW_022145611.1_36506506     0.1  NW_022145611.1_36506506
# 3    NW_022145599.1_23380763     0.1  NW_022145599.1_23380763
# 4    NW_022145601.1_22443666  0.1001  NW_022145601.1_22443666
# 5    NW_022145615.1_23388979  0.1001  NW_022145615.1_23388979
# ..                       ...     ...                      ...
# 249  NW_022145603.1_26343419  0.1553  NW_022145603.1_26343419
# 250  NW_022145599.1_23070922  0.1562  NW_022145599.1_23070922
# 251  NW_022145615.1_25383710  0.1668  NW_022145615.1_25383710
# 252    NW_022145598.1_416271  0.1732    NW_022145598.1_416271
# 253  NW_022145613.1_22684111   0.195  NW_022145613.1_22684111
#
# [253 rows x 3 columns]

# %%
#t=loci.chr.to_numpy()
#chrs=[i.split("_")[:2] for i in t ]
#chrs =["_".join(i) for i in chrs]
#pos=[i.split("_")[2] for i in t ]
#fixed_loci = pd.DataFrame(list(zip(chrs, pos)), columns =['chr', 'pos'])
#np.savetxt("fixed_loci.csv", t, delimiter=',', fmt="%s")

# %% [markdown]
# #---------------------------------------

# %%
new_df=pd.DataFrame()
for index, row in loci.iterrows():
    ch = row[0].split("_")[:2]
    ch = "_".join(ch)
    pos = int(row[0].split("_")[2])
    temp=df[(df['chr']==ch) & (df['start']<=pos) & (df['stop']>=pos)]
    if len(temp) == 0:
        #print("not in annotation")
        new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "not_annot", "gene" : "NA"},  
                        ignore_index = True) 
    if len(temp) == 1:
        print("only one")
        print(temp['type'])
    if len(temp) > 1:
        #print("more than 1")
        #checking for gene overlap
        ids=[]
        for i in range(len(temp)):
            t=temp["info"].iloc[i].split(";")
            res = list(filter(lambda x: "LOC" in x, t))
            if len(res) == 0:
                res = list(filter(lambda x: "GeneID:" in x, t))
                if len(res) != 0:
                    ID = res[0].split("GeneID:",1)[1]
                    ids.append(ID)
                #else:
                    #print(temp["type"].iloc[i])
                    #if temp["type"].iloc[i] == "cDNA_match":
                        #print("cDNA_match")
                    #else:
                        #print("what about ids???")
                        #print(t)
            else:
                ID =res[0].split("LOC",1)[1]
                ids.append(ID)
        uni=len(Counter(ids))
        gene_name = ids[0]
        if uni > 1:
            #print("genes overlap")
            new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "genes_overlap", "gene": "NA"},  
                        ignore_index = True) 
        
        if uni == 1:
            if temp['type'].str.contains('gene').any():
                if temp['type'].str.contains('pseudogene').any():
                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "pseudogene", "gene":"NA" },ignore_index = True)
                # snRNA, tRNA, lnc_RNA, snoRNA, rRNA, miRNA also have line with "gene"
                elif temp['type'].str.contains('snRNA').any():
                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "snRNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('tRNA').any():
                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "tRNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('lnc_RNA').any():
                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "lnc_RNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('snoRNA').any():
                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "snoRNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('rRNA').any():
                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "rRNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('miRNA').any():
                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "miRNA", "gene":ids[0] },ignore_index = True)
                else:
                    if temp['type'].str.contains('exon').any(): 
                        if temp['type'].str.contains('CDS').any():
                            #print("in exon")
                            new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "exon", "gene":f"LOC{ids[0]}" },ignore_index = True) 
                        else:
                            direction=temp['s2'].iloc[0]
                            e_start=temp[temp["type"]=="exon"].iloc[0].start
                            e_stop=temp[temp["type"]=="exon"].iloc[0].stop
                            g_start=temp[temp["type"]=="gene"].iloc[0].start
                            g_stop=temp[temp["type"]=="gene"].iloc[0].stop
                            if direction == "+":
                                if e_start == g_start:
                                    #print('5prime1')
                                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "5'UTR", "gene":f"LOC{ids[0]}" },ignore_index = True) 
                                elif e_stop == g_stop:
                                    #print("3prime1")
                                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "3'UTR", "gene":f"LOC{ids[0]}" },ignore_index = True) 
                                else:
                                    print(index) #alternative UTR?
                                    #print(temp)
                                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "alternative UTR", "gene":"NA" },ignore_index = True) 
                            elif direction == "-":
                                if e_start == g_start:
                                    #print('3prime2')
                                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "3'UTR", "gene":f"LOC{ids[0]}" },ignore_index = True) 
                                elif e_stop == g_stop:
                                    #print("5prime2")
                                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "5'UTR", "gene":f"LOC{ids[0]}" },ignore_index = True)
                                else:
                                    #print("ERROR2")
                                    new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "alternative UTR", "gene":"NA" },ignore_index = True) 
                            else:
                                print(index)
                                #print(temp)

                    else:
                        #print("in intron")
                        new_df = new_df.append({'chr' : ch, 'pos' : pos, 'hol' : "intron", "gene":f"LOC{ids[0]}" },ignore_index = True) 

            else:
                print("not gene")
# Out:
# 76
# 96

# %%
overl = new_df[new_df['hol']=="genes_overlap"]

# %%
overl
# Out:
#                 chr gene            hol         pos
# 202  NW_022145614.1   NA  genes_overlap  18968401.0

# %%
new_df2=pd.DataFrame()
for index, row in overl.iterrows():
    ch = row.chr
    pos = int(row.pos)
    temp=df[(df['chr']==ch) & (df['start']<=pos) & (df['stop']>=pos)]
    if len(temp) == 0:
        #print("not in annotation")
        new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "not_annot", "gene" : "NA"},  
                        ignore_index = True) 
    if len(temp) == 1:
        print("only one")
        print(temp['type'])
    if len(temp) > 1:
        #print("more than 1")
        #checking for gene overlap
        ids=[]
        for i in range(len(temp)):
            t=temp["info"].iloc[i].split(";")
            res = list(filter(lambda x: "LOC" in x, t))
            if len(res) == 0:
                res = list(filter(lambda x: "GeneID:" in x, t))
                if len(res) != 0:
                    ID = res[0].split("GeneID:",1)[1]
                    ids.append(ID)
                #else:
                    #print(temp["type"].iloc[i])
                    #if temp["type"].iloc[i] == "cDNA_match":
                        #print("cDNA_match")
                    #else:
                        #print("what about ids???")
                        #print(t)
            else:
                ID =res[0].split("LOC",1)[1]
                ids.append(ID)
        uni=len(Counter(ids))
        all_loc=Counter(ids)
    
        for i in all_loc:
            #print(i) #gets loci names
            gt=df[(df['chr']==ch) & (df['start']<=pos) & (df['stop']>=pos) & (df['info'].str.contains(i)) ]
            if gt['type'].str.contains('gene').any():
                if gt['type'].str.contains('pseudogene').any():
                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "pseudogene", "gene":"NA" },ignore_index = True)
                # snRNA, tRNA, lnc_RNA, snoRNA, rRNA, miRNA also have line with "gene"
                elif gt['type'].str.contains('snRNA').any():
                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "snRNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('tRNA').any():
                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "tRNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('lnc_RNA').any():
                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "lnc_RNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('snoRNA').any():
                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "snoRNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('rRNA').any():
                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "rRNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('miRNA').any():
                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "miRNA", "gene":i },ignore_index = True)
                else:
                    if gt['type'].str.contains('exon').any(): 
                        if gt['type'].str.contains('CDS').any():
                            #print("in exon")
                            new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "exon", "gene":f"LOC{i}" },ignore_index = True) 
                        else:
                            direction=gt['s2'].iloc[0]
                            e_start=gt[gt["type"]=="exon"].iloc[0].start
                            e_stop=gt[gt["type"]=="exon"].iloc[0].stop
                            g_start=gt[gt["type"]=="gene"].iloc[0].start
                            g_stop=gt[gt["type"]=="gene"].iloc[0].stop
                            if direction == "+":
                                if e_start == g_start:
                                    #print('5prime1')
                                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "5'UTR", "gene":f"LOC{i}" },ignore_index = True) 
                                elif e_stop == g_stop:
                                    #print("3prime1")
                                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "3'UTR", "gene":f"LOC{i}" },ignore_index = True) 
                                else:
                                    print(index) #alternative UTR?
                                    #print(gt)
                                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "alternative UTR", "gene":"NA" },ignore_index = True) 
                            elif direction == "-":
                                if e_start == g_start:
                                    #print('3prime2')
                                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "3'UTR", "gene":f"LOC{i}" },ignore_index = True) 
                                elif e_stop == g_stop:
                                    #print("5prime2")
                                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "5'UTR", "gene":f"LOC{i}" },ignore_index = True)
                                else:
                                    #print("ERROR2")
                                    new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "alternative UTR", "gene":"NA" },ignore_index = True) 
                            else:
                                print(index)
                                #print(gt)

                    else:
                        #print("in intron")
                        new_df2 = new_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "intron", "gene":f"LOC{i}" },ignore_index = True) 

            else:
                print("not gene")

# %%
new_df.pos = new_df.pos.astype(int)
new_df2.pos = new_df2.pos.astype(int)

# %%
new_df.to_csv("annotated_top_goodhe_01.csv",index=False)

# %%
new_df2.to_csv("annotated_top_goodhe_01_overlap.csv",index=False)

# %%
len(new_df[new_df["hol"]=="not_annot"])
# Out:
# 111

# %% [markdown]
# #---------------------------------------

# %%
new_df = pd.read_csv('annotated_top_goodhe_01.csv')
new_df2 = pd.read_csv('annotated_top_goodhe_01_overlap.csv')

# %%
promoters = pd.read_csv('all_annotations.txt', sep="\t", header=None, names=["chr","source","type","start","stop","s1","s2","s3","info"])
#promoters = promoters[promoters['type']=="gene"]

promoters.drop(promoters[promoters['type'] == "region"].index, inplace = True)


imp_list=["gene","snRNA", "tRNA", "lnc_RNA", "snoRNA", "rRNA", "miRNA"]
for l in imp_list:
    promoters.loc[(promoters["type"]==l) & (promoters["s2"]=="+"), "start"] -= 1000
    promoters.loc[(promoters["type"]==l) & (promoters["s2"]=="-"), "stop"] += 1000

promoters['info'] = promoters['info'].str.replace(',',';')

# %%
mis = new_df[new_df['hol']=="not_annot"]

# %%
mis
# Out:
#                  chr gene        hol       pos
# 0     NW_022145599.1  NaN  not_annot    809765
# 1     NW_022145613.1  NaN  not_annot  22684111
# 2     NW_022145600.1  NaN  not_annot  36849648
# 3     NW_022145612.1  NaN  not_annot  13121687
# 4     NW_022145595.1  NaN  not_annot  20882520
# ...              ...  ...        ...       ...
# 6839  NW_022145600.1  NaN  not_annot  16153542
# 6840  NW_022145599.1  NaN  not_annot  23380763
# 6842  NW_022145597.1  NaN  not_annot  27269202
# 6843  NW_022145597.1  NaN  not_annot  25996126
# 6845  NW_022145595.1  NaN  not_annot   3170334
#
# [2934 rows x 4 columns]

# %%
prom_df=pd.DataFrame()
for index, row in mis.iterrows():
    ch = row.chr
    pos = int(row.pos)
    temp=promoters[(promoters['chr']==ch) & (promoters['start']<=pos) & (promoters['stop']>=pos)]
    if len(temp) == 0:
        #print("not in annotation")
        prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "not_annot", "gene" : "NA"},  
                        ignore_index = True) 
    else:
        ids=[]
        for i in range(len(temp)):
            t=temp["info"].iloc[i].split(";")
            res = list(filter(lambda x: "LOC" in x, t))
            if len(res) == 0:
                res = list(filter(lambda x: "GeneID:" in x, t))
                if len(res) != 0:
                    ID = res[0].split("GeneID:",1)[1]
                    #print(ID)
                    ids.append(ID)
               # else:
                    #print(temp["type"].iloc[i])
                    #if temp["type"].iloc[i] == "cDNA_match":
                        #print("cDNA_match")
                        #print(ID)
                    #else:
                        #print("what about ids???")
                        #print(t)
            else:
                ID =res[0].split("LOC",1)[1]
                ids.append(ID)
        uni=len(Counter(ids))
        gene_name = ids[0]
        if uni > 1:
            #print("genes overlap")
            prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "genes_overlap", "gene": "NA"},  
                        ignore_index = True) 
        
        if uni == 1:
            #print("new")
            if temp['type'].str.contains('gene').any():
                if temp['type'].str.contains('pseudogene').any():
                    prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "pseudogene", "gene":"NA" },ignore_index = True)
                # snRNA, tRNA, lnc_RNA, snoRNA, rRNA, miRNA also have line with "gene"
                elif temp['type'].str.contains('snRNA').any():
                    prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "snRNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('tRNA').any():
                    prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "tRNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('lnc_RNA').any():
                    prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "lnc_RNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('snoRNA').any():
                    prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "snoRNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('rRNA').any():
                    prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "rRNA", "gene":ids[0] },ignore_index = True)
                elif temp['type'].str.contains('miRNA').any():
                    prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "miRNA", "gene":ids[0] },ignore_index = True)
                else:    
                    prom_df = prom_df.append({'chr' : ch, 'pos' : pos, 'hol' : "protein_coding", "gene" : f"LOC{gene_name}"},  
                                    ignore_index = True)

# %%
prom_df[(prom_df["hol"]!="protein_coding") & (prom_df["hol"]!="not_annot")]
# Out:
#                  chr       gene            hol         pos
# 154   NW_022145606.1  115927542        lnc_RNA  51617618.0
# 299   NW_022145610.1  105439156        lnc_RNA   4464029.0
# 377   NW_022145612.1  115919527        lnc_RNA   5147427.0
# 380   NW_022145604.1         NA  genes_overlap   4431805.0
# 541   NW_022145609.1         NA  genes_overlap  38496531.0
# 579   NW_022145612.1  115919686           tRNA  29121669.0
# 1145  NW_022145595.1  115921769        lnc_RNA  26982685.0
# 1274  NW_022145597.1         NA  genes_overlap  18694201.0
# 1693  NW_022145597.1  105436976        lnc_RNA  29688422.0
# 1705  NW_022145597.1         NA  genes_overlap   1832731.0
# 1813  NW_022145615.1         NA  genes_overlap   7003765.0
# 1927  NW_022145607.1         NA  genes_overlap  39221355.0
# 1992  NW_022145606.1  115927542        lnc_RNA  51617558.0
# 2080  NW_022145594.1  115921049        lnc_RNA  32277738.0
# 2371  NW_022145596.1         NA  genes_overlap  29277296.0
# ...

# %%
prom_overl = prom_df[prom_df['hol']=="genes_overlap"]

# %%
prom_overl
# Out:
#                  chr gene            hol         pos
# 380   NW_022145604.1   NA  genes_overlap   4431805.0
# 541   NW_022145609.1   NA  genes_overlap  38496531.0
# 1274  NW_022145597.1   NA  genes_overlap  18694201.0
# 1705  NW_022145597.1   NA  genes_overlap   1832731.0
# 1813  NW_022145615.1   NA  genes_overlap   7003765.0
# 1927  NW_022145607.1   NA  genes_overlap  39221355.0
# 2371  NW_022145596.1   NA  genes_overlap  29277296.0
# 2433  NW_022145615.1   NA  genes_overlap   7003884.0
# 2572  NW_022145615.1   NA  genes_overlap  13279159.0

# %%
prom_df2=pd.DataFrame()
for index, row in prom_overl.iterrows():
    ch = row.chr
    pos = int(row.pos)
    temp=promoters[(promoters['chr']==ch) & (promoters['start']<=pos) & (promoters['stop']>=pos)]
    if len(temp) == 0:
        #print("not in annotation")
        prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "not_annot", "gene" : "NA"},  
                        ignore_index = True) 
    else:
        ids=[]
        for i in range(len(temp)):
            t=temp["info"].iloc[i].split(";")
            res = list(filter(lambda x: "LOC" in x, t))
            if len(res) == 0:
                res = list(filter(lambda x: "GeneID:" in x, t))
                if len(res) != 0:
                    ID = res[0].split("GeneID:",1)[1]
                    #print(ID)
                    ids.append(ID)
                #else:
                    #print(temp["type"].iloc[i])
                    #if temp["type"].iloc[i] == "cDNA_match":
                       # print("cDNA_match")
                        #print(ID)
                   # else:
                       # print("what about ids???")
                       # print(t)
            else:
                ID =res[0].split("LOC",1)[1]
                ids.append(ID)
        uni=len(Counter(ids))
        gene_name = ids[0]
        all_loc=Counter(ids)
        
        for i in all_loc:
            #print(i) #gets loci names
            gt=promoters[(promoters['chr']==ch) & (promoters['start']<=pos) & (promoters['stop']>=pos) & (promoters['info'].str.contains(i)) ]
            print(gt)
            if gt['type'].str.contains('gene').any():
                if gt['type'].str.contains('pseudogene').any():
                    prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "pseudogene", "gene":"NA" },ignore_index = True)
                # snRNA, tRNA, lnc_RNA, snoRNA, rRNA, miRNA also have line with "gene"
                elif gt['type'].str.contains('snRNA').any():
                    prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "snRNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('tRNA').any():
                    prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "tRNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('lnc_RNA').any():
                    prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "lnc_RNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('snoRNA').any():
                    prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "snoRNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('rRNA').any():
                    prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "rRNA", "gene":i },ignore_index = True)
                elif gt['type'].str.contains('miRNA').any():
                    prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "miRNA", "gene":i },ignore_index = True)
                else:
                    prom_df2 = prom_df2.append({'chr' : ch, 'pos' : pos, 'hol' : "protein_coding", "gene":f"LOC{i}" },ignore_index = True)
# Out:
#                    chr       source  type    start     stop s1 s2 s3  \
# 434607  NW_022145604.1  tRNAscan-SE  gene  4430754  4431826  .  -  .
# 434608  NW_022145604.1  tRNAscan-SE  tRNA  4430754  4431826  .  -  .
#
#                                                      info
# 434607  ID=gene-TRNAR-UCG-22;Dbxref=GeneID:115926272;N...
# 434608  ID=rna-TRNAR-UCG-22;Parent=gene-TRNAR-UCG-22;D...
#                    chr       source  type    start     stop s1 s2 s3  \
# 434610  NW_022145604.1  tRNAscan-SE  gene  4430931  4432003  .  -  .
# 434611  NW_022145604.1  tRNAscan-SE  tRNA  4430931  4432003  .  -  .
#
#                                                      info
# 434610  ID=gene-TRNAR-UCG-23;Dbxref=GeneID:115926273;N...
# 434611  ID=rna-TRNAR-UCG-23;Parent=gene-TRNAR-UCG-23;D...
#                    chr       source  type    start     stop s1 s2 s3  \
# 434613  NW_022145604.1  tRNAscan-SE  gene  4431107  4432178  .  -  .
# ...

# %%
prom_df2.hol.unique()
# Out:
# array(['tRNA', 'protein_coding', 'lnc_RNA'], dtype=object)

# %%
len(prom_df[prom_df["hol"]=="protein_coding"])
# Out:
# 142

# %%
len(prom_df2[prom_df2["hol"]=="lnc_RNA"])
# Out:
# 1

# %%
prom_df[prom_df["hol"]=="genes_overlap"]
# Out:
#                  chr gene            hol         pos
# 380   NW_022145604.1   NA  genes_overlap   4431805.0
# 541   NW_022145609.1   NA  genes_overlap  38496531.0
# 1274  NW_022145597.1   NA  genes_overlap  18694201.0
# 1705  NW_022145597.1   NA  genes_overlap   1832731.0
# 1813  NW_022145615.1   NA  genes_overlap   7003765.0
# 1927  NW_022145607.1   NA  genes_overlap  39221355.0
# 2371  NW_022145596.1   NA  genes_overlap  29277296.0
# 2433  NW_022145615.1   NA  genes_overlap   7003884.0
# 2572  NW_022145615.1   NA  genes_overlap  13279159.0

# %%
len(prom_df[(prom_df["hol"]!="genes_overlap") & (prom_df["hol"]!="not_annot")])
# Out:
# 151

# %% [markdown]
# #------------------------------------------------

# %% [markdown]
# ## now let's see if there is any in enhancer, outside of intron

# %% [markdown]
# are intronic ones located in:
#     1 ATAC
#     2 lvar
#     3 chip
#     4 lnc
#     5 promoter
#     6 TFBS

# %%
promoters = pd.read_csv('all_annotations.txt', sep="\t", header=None, names=["chr","source","type","start","stop","s1","s2","s3","info"])
promoters = promoters[promoters['type']=="gene"]

promoters.loc[(promoters["type"]=="gene") & (promoters["s2"]=="+"), "start"] -= 1000
promoters.loc[(promoters["type"]=="gene") & (promoters["s2"]=="-"), "stop"] += 1000

# %%
atac = pd.read_csv("atac_mapped_translatedto5.0.csv", header=None, names=["chr","start","stop"])
chip = pd.read_csv('AlxChip_mapped_translatedto5.0.txt', sep="\t", header=None, names=["chr","start","stop"])
lvar = pd.read_csv('lvar_spur_48_50_mapped_translatedto50.csv', header=None, names=["chr","start","stop"])
lnc = pd.read_csv("lncRNA_mapped_translatedto5.0.csv", header=1, names=["chr","start","stop"])

# %%
mis = new_df[new_df['hol']=="not_annot"]

# %%
enh_check=pd.DataFrame()
for index, row in mis.iterrows():
    ch = row.chr
    pos = row.pos
    temp=atac[(atac['chr']==ch) & (atac['start']<=pos) & (atac['stop']>=pos)]
    if len(temp) > 0:
        print("in atac")
        enh_check = enh_check.append({'chr' : ch, 'pos' : pos, 'hol' : "atac" },ignore_index = True) 
    temp=chip[(chip['chr']==ch) & (chip['start']<=pos) & (chip['stop']>=pos)]
    if len(temp) > 0:
        print("in chip")
        enh_check = enh_check.append({'chr' : ch, 'pos' : pos, 'hol' : "chip" },ignore_index = True)
    temp=lvar[(lvar['chr']==ch) & (lvar['start']<=pos) & (lvar['stop']>=pos)]
    if len(temp) > 0:
        print("in lvar")
        enh_check = enh_check.append({'chr' : ch, 'pos' : pos, 'hol' : "lvar" },ignore_index = True)
    temp=lnc[(lnc['chr']==ch) & (lnc['start']<=pos) & (lnc['stop']>=pos)]
    if len(temp) > 0:
        print("in lnc")
        enh_check = enh_check.append({'chr' : ch, 'pos' : pos, 'hol' : "lnc" },ignore_index = True)
    temp=promoters[(promoters['chr']==ch) & (promoters['start']<=pos) & (promoters['stop']>=pos)]
    if len(temp) > 0:
        print("in promoters")
        enh_check = enh_check.append({'chr' : ch, 'pos' : pos, 'hol' : "promoter" },ignore_index = True)
# Out:
# in lnc
# in lnc
# in promoters
# in lnc
# in promoters
# in lnc
# in lnc
# in lnc
# in promoters
# in promoters
# in lnc
# in lnc

# %%
enh_check.hol.unique()
# Out:
# array(['lnc', 'promoter'], dtype=object)

# %%
len(enh_check[enh_check["hol"]=="lnc"])
# Out:
# 8

# %%
pot_en = enh_check[(enh_check["hol"]=="lvar") | (enh_check["hol"]=="chip")]

# %%
pot_en=pot_en.sort_values(by=["chr",'pos'])

# %%
len(pot_en)
# Out:
# 19

# %%
#reminder: chosen atac supp (or lvar or chip) too strict?

# %% [markdown]
# ## now let's see if there is any in enhancer, inside of intron

# %%
mis = new_df[new_df['hol']=="intron"]

# %%
int_check=pd.DataFrame()
for index, row in mis.iterrows():
    ch = row.chr
    pos = row.pos
    gene=row.gene
    temp=atac[(atac['chr']==ch) & (atac['start']<=pos) & (atac['stop']>=pos)]
    if len(temp) > 0:
        print("in atac")
        int_check = int_check.append({'chr' : ch, 'pos' : pos, 'hol' : "atac",'gene':gene },ignore_index = True) 
    temp=chip[(chip['chr']==ch) & (chip['start']<=pos) & (chip['stop']>=pos)]
    if len(temp) > 0:
        print("in chip")
        int_check = int_check.append({'chr' : ch, 'pos' : pos, 'hol' : "chip",'gene':gene },ignore_index = True)
    temp=lvar[(lvar['chr']==ch) & (lvar['start']<=pos) & (lvar['stop']>=pos)]
    if len(temp) > 0:
        print("in lvar")
        int_check = int_check.append({'chr' : ch, 'pos' : pos, 'hol' : "lvar",'gene':gene },ignore_index = True)
    temp=lnc[(lnc['chr']==ch) & (lnc['start']<=pos) & (lnc['stop']>=pos)]
    if len(temp) > 0:
        print("in lnc")
        int_check = int_check.append({'chr' : ch, 'pos' : pos, 'hol' : "lnc",'gene':gene },ignore_index = True)
# Out:
# in lnc

# %%
int_check.hol.unique()
# Out:
# array(['lnc'], dtype=object)

# %%
int_check[int_check["hol"]=="lnc"]
# Out:
#                 chr          gene  hol         pos
# 0    NW_022145601.1  LOC100894079  lnc  22606114.0
# 1    NW_022145612.1     LOC579367  lnc  41191507.0
# 2    NW_022145614.1  LOC105444100  lnc  20905720.0
# 3    NW_022145610.1  LOC105444622  lnc   1523941.0
# 4    NW_022145543.1  LOC115917929  lnc    956594.0
# ..              ...           ...  ...         ...
# 124  NW_022145615.1  LOC100892961  lnc  29040288.0
# 125  NW_022145612.1     LOC762981  lnc   5104468.0
# 126  NW_022145598.1  LOC105444132  lnc  17378166.0
# 127  NW_022145576.1  LOC100891941  lnc   2132339.0
# 129  NW_022145605.1  LOC100893229  lnc  22327453.0
#
# [118 rows x 4 columns]

# %%
pot_in = int_check[(int_check["hol"]=="lvar") | (int_check["hol"]=="chip") | (int_check["hol"]=="atac")]

# %%
pot_in=pot_in.sort_values(by=["chr",'pos'])

# %%
pot_in
# Out:
#                 chr          gene   hol         pos
# 86   NW_022145600.1     LOC577823  lvar  18662627.0
# 34   NW_022145601.1     LOC754783  chip   5003800.0
# 75   NW_022145604.1     LOC582776  lvar   8855042.0
# 106  NW_022145605.1     LOC588549  lvar  16695182.0
# 37   NW_022145609.1  LOC105445730  chip   1841502.0
# 91   NW_022145610.1  LOC100894087  lvar  35316800.0
# 55   NW_022145612.1  LOC105447203  chip  11733562.0
# 128  NW_022145612.1     LOC580713  lvar  14929793.0
# 13   NW_022145612.1     LOC582326  chip  17759074.0
# 88   NW_022145612.1     LOC580332  lvar  47720769.0
# 23   NW_022145613.1     LOC581963  atac  38079900.0
# 104  NW_022145613.1     LOC581963  atac  38080603.0

# %%
new_df
# Out:
#                  chr       gene              hol       pos
# 0     NW_022145599.1        NaN        not_annot    809765
# 1     NW_022145613.1        NaN        not_annot  22684111
# 2     NW_022145600.1        NaN        not_annot  36849648
# 3     NW_022145612.1        NaN        not_annot  13121687
# 4     NW_022145595.1        NaN        not_annot  20882520
# ...              ...        ...              ...       ...
# 6842  NW_022145597.1        NaN        not_annot  27269202
# 6843  NW_022145597.1        NaN        not_annot  25996126
# 6844  NW_022145596.1        NaN  alternative UTR  12214610
# 6845  NW_022145595.1        NaN        not_annot   3170334
# 6846  NW_022145595.1  LOC582877           intron  16380245
#
# [6847 rows x 4 columns]

# %% [markdown]
# ## Biomin genes

# %%
#new_dff = pd.read_csv('annotated_top_goodhe_01_overlap.csv')
new_df =new_df.dropna()
new_df2 =new_df2.dropna()
#prom_df =prom_df.dropna()
#prom_df2 =prom_df2.dropna()

# %%
#comb_set=set(list(new_dff[new_dff["gene"].str.contains("LOC")].gene))

# %%
oloc=list(new_df[new_df["gene"].str.contains("LOC")].gene)

# %%
nloc=list(new_df2[new_df2["gene"].str.contains("LOC")].gene)

# %%
oploc=list(prom_df[prom_df["gene"].str.contains("LOC")].gene)
nploc=list(prom_df2[prom_df2["gene"].str.contains("LOC")].gene)

# %%
comb_set=set(oloc + nloc)# + oploc + nploc)

# %%
comb_set
# Out:
# {'LOC100888258',
#  'LOC100888559',
#  'LOC100888919',
#  'LOC100888943',
#  'LOC100889081',
#  'LOC100889178',
#  'LOC100889636',
#  'LOC100890044',
#  'LOC100890291',
#  'LOC100890901',
#  'LOC100891054',
#  'LOC100891151',
#  'LOC100891656',
#  'LOC100892015',
#  'LOC100892245',
#  'LOC100893334',
#  'LOC100893463',
#  'LOC100893580',
#  'LOC100893707',
#  'LOC100893741',
#  'LOC100893814',
#  'LOC105436405',
#  'LOC105436540',
#  'LOC105436858',
#  'LOC105437164',
#  'LOC105437450',
#  'LOC105437610',
#  'LOC105437744',
#  'LOC105440755',
#  'LOC105441802',
#  'LOC105443575',
#  'LOC105444109',
#  'LOC105444601',
#  'LOC105445286',
#  'LOC105445349',
#  'LOC105446050',
#  'LOC105446450',
#  'LOC115918170',
#  'LOC115918473',
#  'LOC115920308',
#  'LOC115920337',
#  'LOC115921812',
#  'LOC115926117',
#  'LOC115927664',
#  'LOC115927899',
#  'LOC115928085',
#  'LOC115929921',
#  'LOC575136',
#  'LOC575196',
#  'LOC575433',
#  'LOC575587',
#  'LOC575771',
#  'LOC575816',
# ...

# %%
mappin = pd.read_csv('SPU_LOC_echino.csv', sep=",", names=['genepage','locname', 'info', 'vmi1','vmi2','vmi3','vmi4'])

# %%
mappin=mappin.drop(columns=['vmi1',"vmi3","vmi4"])

# %%
mappin.drop(mappin[mappin['vmi2'] == "Manually curated"].index, inplace = True)
mappin.drop(mappin[mappin['vmi2'] == "Algorithmically generated"].index, inplace = True)

# %%
mappin=mappin.dropna()

# %%
my_spus = mappin[mappin['vmi2'].str.contains('SPU')]

# %%
from collections import defaultdict

mapping = defaultdict(list)

for _, (locname, vmi) in my_spus[['locname','vmi2']].iterrows():
    
    candidates = vmi.split("|")
    spus = [el for el in candidates if "SPU" in el]
    locs = [el for el in candidates if "LOC" in el]
    if "LOC" in locname:
        locs.append(locname)
        
    for spu in spus:
        for loc in locs:
            mapping[spu].append(loc)
        
mapping = dict(mapping)

# %%
mapping["SPU_023201"]
# Out:
# ['LOC582406', 'LOC110987996']

# %%
#i was here with checking high bayenv

# %%
erd = pd.read_csv('regulator.csv', header=None, names=["chr","start","stop","hol"],dtype=object)

# %%
erd
# Out:
#            chr start stop  hol
# 0    100888859   NaN  NaN  NaN
# 1    100889578   NaN  NaN  NaN
# 2    100889729   NaN  NaN  NaN
# 3    100889993   NaN  NaN  NaN
# 4    100891144   NaN  NaN  NaN
# ..         ...   ...  ...  ...
# 758  100891319   NaN  NaN  NaN
# 759  100891398   NaN  NaN  NaN
# 760  100893779   NaN  NaN  NaN
# 761     373229   NaN  NaN  NaN
# 762     373404   NaN  NaN  NaN
#
# [763 rows x 4 columns]

# %%
#erd["f"]="LOC" + erd["chr"]

# %%
#alt_genes=set(erd.f.to_numpy())

# %%
genes=erd.chr.to_numpy()

# %%
alt_genes=set()
for gene in genes:
    if gene in mapping:
        alt = mapping[gene]
        for el in alt:
            alt_genes.add(el)

# %%
len(alt_genes)
# Out:
# 763

# %%
alt_genes
# Out:
# {'LOC100887874',
#  'LOC100887881',
#  'LOC100887895',
#  'LOC100887976',
#  'LOC100887987',
#  'LOC100888100',
#  'LOC100888106',
#  'LOC100888144',
#  'LOC100888163',
#  'LOC100888173',
#  'LOC100888193',
#  'LOC100888229',
#  'LOC100888264',
#  'LOC100888276',
#  'LOC100888309',
#  'LOC100888349',
#  'LOC100888350',
#  'LOC100888404',
#  'LOC100888418',
#  'LOC100888427',
#  'LOC100888432',
#  'LOC100888460',
#  'LOC100888466',
#  'LOC100888482',
#  'LOC100888492',
#  'LOC100888504',
#  'LOC100888536',
#  'LOC100888596',
#  'LOC100888619',
#  'LOC100888640',
#  'LOC100888664',
#  'LOC100888674',
#  'LOC100888705',
#  'LOC100888710',
#  'LOC100888724',
#  'LOC100888741',
#  'LOC100888758',
#  'LOC100888777',
#  'LOC100888783',
#  'LOC100888798',
#  'LOC100888859',
#  'LOC100888872',
#  'LOC100888880',
#  'LOC100888889',
#  'LOC100888898',
#  'LOC100888945',
#  'LOC100889015',
#  'LOC100889018',
#  'LOC100889019',
#  'LOC100889107',
#  'LOC100889161',
#  'LOC100889197',
# ...

# %%
comb_set
# Out:
# {'LOC100888721',
#  'LOC100892305',
#  'LOC585380',
#  'LOC579152',
#  'LOC100888805',
#  'LOC756379',
#  'LOC577683',
#  'LOC576228',
#  'LOC763804',
#  'LOC100889593',
#  'LOC584537',
#  'LOC577766',
#  'LOC100891134',
#  'LOC576508',
#  'LOC583289',
#  'LOC578469',
#  'LOC100893146',
#  'LOC577291',
#  'LOC577545',
#  'LOC100892160',
#  'LOC763369',
#  'LOC764101',
#  'LOC577313',
#  'LOC100890361',
#  'LOC105446972',
#  'LOC105447312',
#  'LOC590237',
#  'LOC105443094',
#  'LOC115922139',
#  'LOC593302',
#  'LOC105441802',
#  'LOC105446450',
#  'LOC577155',
#  'LOC757176',
#  'LOC576978',
#  'LOC592598',
#  'LOC105442195',
#  'LOC754388',
#  'LOC100892211',
#  'LOC584564',
#  'LOC548623',
#  'LOC585283',
#  'LOC580955',
#  'LOC580066',
#  'LOC583510',
#  'LOC594712',
#  'LOC594342',
#  'LOC576998',
#  'LOC115927876',
#  'LOC100888744',
#  'LOC586138',
#  'LOC583749',
#  'LOC594043',
#  'LOC115921855',
#  'LOC582885',
#  'LOC115920679',
#  'LOC574747',
#  'LOC105444822',
# ...

# %%
len(comb_set.intersection(alt_genes))
# Out:
# 128

# %%
comb_set.intersection(alt_genes)
# Out:
# {'LOC100890645',
#  'LOC100892375',
#  'LOC100893839',
#  'LOC576535',
#  'LOC576799',
#  'LOC577426',
#  'LOC577766',
#  'LOC581625',
#  'LOC581867',
#  'LOC585260',
#  'LOC585636',
#  'LOC587946',
#  'LOC588089',
#  'LOC589006',
#  'LOC591691',
#  'LOC591914',
#  'LOC756958'}

# %%
new_df[new_df['gene']=="LOC756958"]
# Out:
#                  chr       gene     hol      pos
# 6238  NW_022145610.1  LOC756958  intron  3918069

# %%
prom_df[prom_df['gene']=="LOC575445"]
# Out:
#                 chr       gene             hol         pos
# 485  NW_022145598.1  LOC575445  protein_coding  20730134.0

# %%
from random import choice


choice(list(comb_set.intersection(alt_genes)))
# Out:
# 'LOC587946'

# %% [markdown]
# ## let's check for my old list (what i wanted to get probes for)

# %%
erd = pd.read_csv('my_old_list.csv', header=None, names=["chr","start","stop","hol"])

# %%
erd
# Out:
#                 chr       start        stop        hol
# 0        Chromosome       Start         End       Gene
# 1    NW_022145611.1  20239836.0  20262988.0        Otx
# 2    NW_022145613.1  19666380.0  19695392.0  B-catenin
# 3    NW_022145607.1  33413785.0  33447745.0     Blimp1
# 4    NW_022145595.1   3234303.0   3240831.0       Wnt8
# ..              ...         ...         ...        ...
# 125             NaN         NaN         NaN        NaN
# 126             NaN         NaN         NaN        NaN
# 127             NaN         NaN         NaN        NaN
# 128             NaN         NaN         NaN        NaN
# 129             NaN         NaN         NaN        NaN
#
# [130 rows x 4 columns]

# %%
erd.drop([0], inplace = True)

# %%
erd=erd.dropna()

# %%
erd["start"]=erd.start.astype(float)
erd["stop"]=erd.stop.astype(float)
# Out:
# <ipython-input-233-fc4b1870e431>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   erd["start"]=erd.start.astype(float)
# <ipython-input-233-fc4b1870e431>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   erd["stop"]=erd.stop.astype(float)

# %%
erd["hol"].iloc[0]
# Out:
# 'Otx'

# %%
erd_check=pd.DataFrame()
for index, row in loci.iterrows():
    ch = row[0].split("_")[:2]
    ch = "_".join(ch)
    pos = int(row[0].split("_")[2])
    fst = row[1]
    temp= erd[(erd['chr']==ch) & (erd['start']<=pos) & (erd['stop']>=pos)]
    if len(temp) > 0:
        erd_check = erd_check.append({'chr' : ch, 'pos' : pos, 'hol' : temp["hol"].iloc[0], "fst" : fst},ignore_index = True)

# %%
erd_check.sort_values(by=["hol"])
# Out:
#                chr     fst                     hol         pos
# 12  NW_022145615.1  0.1179              ATPsythase  31275084.0
# 31  NW_022145603.1  0.1058                    Alx1  14678986.0
# 30  NW_022145603.1  0.1059                    Alx1  14662026.0
# 26  NW_022145603.1  0.1083                    Alx1  14694778.0
# 8   NW_022145613.1  0.1216               B-catenin  19685318.0
# 0   NW_022145596.1  0.1602                   CA10L  30320957.0
# 43  NW_022145596.1  0.1013                   CA10L  30331129.0
# 18  NW_022145596.1  0.1127                   CA10L  30330987.0
# 34  NW_022145599.1  0.1049                   CD109   3635077.0
# 46  NW_022145597.1  0.1006              COLP3alpha  20094418.0
# 40  NW_022145597.1  0.1020              COLP3alpha  20094442.0
# 47  NW_022145597.1  0.1006              COLP3alpha  20080205.0
# 48  NW_022145597.1  0.1001              COLP3alpha  20071223.0
# 45  NW_022145613.1  0.1010                Cara14la  27358332.0
# ...

# %%
cdf = new_df.merge(erd_check, on=["chr","pos"])

# %%
cdf=cdf.sort_values(by=["hol_y"])

# %%
len(cdf)
# Out:
# 49

# %%
int_check["pos"]=int_check.pos.astype(int)

# %%
int_check
# Out:
#                 chr          gene   hol       pos
# 0    NW_022145601.1  LOC100894079   lnc  22606114
# 1    NW_022145612.1     LOC579367   lnc  41191507
# 2    NW_022145614.1  LOC105444100   lnc  20905720
# 3    NW_022145610.1  LOC105444622   lnc   1523941
# 4    NW_022145543.1  LOC115917929   lnc    956594
# ..              ...           ...   ...       ...
# 125  NW_022145612.1     LOC762981   lnc   5104468
# 126  NW_022145598.1  LOC105444132   lnc  17378166
# 127  NW_022145576.1  LOC100891941   lnc   2132339
# 128  NW_022145612.1     LOC580713  lvar  14929793
# 129  NW_022145605.1  LOC100893229   lnc  22327453
#
# [130 rows x 4 columns]

# %%
check = int_check.merge(cdf, on=["chr","pos"])

# %%
check
# Out:
# Empty DataFrame
# Columns: [chr, gene_x, hol, pos, gene_y, hol_x, fst, hol_y]
# Index: []

# %% [markdown]
# # Go terms

# %%
new_df.hol.unique()
# Out:
# array(['not_annot', 'exon', "3'UTR", 'intron', 'genes_overlap',
#        'alternative UTR', "5'UTR", 'pseudogene'], dtype=object)

# %%
for_go =new_df[(new_df["hol"]=="exon") | (new_df["hol"]=="3'UTR") | (new_df["hol"]=="intron") | (new_df["hol"]=="5'UTR")]

# %%
for_go.to_csv("loci_for_go.csv",index=False)

# %%
genes=for_go.gene.to_numpy()

# %%
with open("SPU_LOC_conv.txt") as f:
    mapping = list(map(lambda x: x.strip().split("\t")[:2],f.readlines()))
    print(mapping[0])
    mapping = {key:val for val,key in mapping[1:]}
# Out:
# ['protein_external_id', 'preferred_name']

# %%
alt_gene=[]
for gene in genes:
    if gene in mapping.keys():
        alt = mapping[gene]
        x = alt.split(".")
        y = x[1].split("-")
        alt_gene.append(y[0])

# %%
np.savetxt("for_go_spus.csv", alt_gene, delimiter=',', fmt="%s")

# %%
len(np.unique(alt_gene))
# Out:
# 980
