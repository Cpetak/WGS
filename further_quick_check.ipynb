# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("big_df_allvars.csv")

# %%
df
# Out:
#        index              ch       pos          gene   ph_mean    ph_var  \
# 0      28119  NW_022145612.1  50053666  LOC100888473  0.170780  0.056826
# 1      16952  NW_022145612.1  50049890  LOC100888473  0.044451  0.037790
# 2      48492  NW_022145612.1  48586134             -  0.033216  0.111070
# 3      48493  NW_022145612.1  48603898             -  0.029832  0.026038
# 4      48494  NW_022145612.1  48637206             -  0.026539  0.033312
# ...      ...             ...       ...           ...       ...       ...
# 61501  31039  NW_022145567.1    519604  LOC100890715  0.037263  0.043926
# 61502  50406  NW_022145555.1    717279  LOC115918890  0.032587  0.159620
# 61503  11090  NW_022145518.1    223420     LOC764237  0.128910  0.071184
# 61504  42046  NW_022145489.1     14494     LOC594069  0.057185  0.032531
# 61505  50357  NW_022145465.1      2097     LOC577919  0.028931  0.028120
#
#        temp_mean  temp_var   ph_freq  ch_num  ...  log_ph_mean  log_ph_var  \
# ...

# %%
temp=df[df["gene"]!="-"]

# %%
temp
# Out:
#        index              ch       pos          gene   ph_mean    ph_var  \
# 0      28119  NW_022145612.1  50053666  LOC100888473  0.170780  0.056826
# 1      16952  NW_022145612.1  50049890  LOC100888473  0.044451  0.037790
# 28109  48495  NW_022145612.1  48661666     LOC582475  0.977220  0.035781
# 28110  16924  NW_022145612.1  48651478     LOC582475  0.052308  0.080398
# 28111   8481  NW_022145612.1  48658344     LOC582475  0.044537  0.106370
# ...      ...             ...       ...           ...       ...       ...
# 61501  31039  NW_022145567.1    519604  LOC100890715  0.037263  0.043926
# 61502  50406  NW_022145555.1    717279  LOC115918890  0.032587  0.159620
# 61503  11090  NW_022145518.1    223420     LOC764237  0.128910  0.071184
# 61504  42046  NW_022145489.1     14494     LOC594069  0.057185  0.032531
# 61505  50357  NW_022145465.1      2097     LOC577919  0.028931  0.028120
#
#        temp_mean  temp_var   ph_freq  ch_num  ...  log_ph_mean  log_ph_var  \
# ...

# %%
t2=temp[temp["w_neighs"]>0]

# %%
t3=t2[t2["exp_level"]>0]

# %%
t3
# Out:
#        index              ch       pos       gene   ph_mean    ph_var  \
# 28385  48562  NW_022145612.1  52109544  LOC580083  0.097494  0.035651
# 28386  28180  NW_022145612.1  52118959  LOC580083  0.039658  0.075917
# 28387  28179  NW_022145612.1  52107519  LOC580083  0.047292  0.037643
# 28388  16986  NW_022145612.1  52118394  LOC580083  0.090410  0.035256
# 28389   8581  NW_022145612.1  52127684  LOC580083  0.055263  0.052312
# ...      ...             ...       ...        ...       ...       ...
# 61143  55351  NW_022145606.1  50173371  LOC574664  0.044330  0.034029
# 61144  36151  NW_022145606.1  50174197  LOC574664  0.109000  0.047349
# 61294  55209  NW_022145606.1   9571794  LOC578859  0.066382  0.066099
# 61469  31000  NW_022145527.1    594100  LOC593816  0.043927  0.042534
# 61471  42055  NW_022145521.1    747251  LOC575609  0.066268  0.042469
#
#        temp_mean  temp_var   ph_freq  ch_num  ...  log_ph_mean  log_ph_var  \
# ...

# %%
808/33399
# Out:
# 0.02419234108805653

# %%
df.iloc[df[['ph_freq',"ph_mean", "temp_mean","temp_var"]].idxmax()]
# Out:
#        index              ch       pos          gene    ph_mean    ph_var  \
# 56033  36890  NW_022145609.1  33060838  LOC100888699   30.58100  0.142310
# 31638  38467  NW_022145612.1    374044     LOC580371  358.86000  0.054769
# 5462   28763  NW_022145613.1  17186308             -   62.06500  0.110530
# 60410   3688  NW_022145602.1  17858768  LOC100888006    0.60554  0.579050
#
#        temp_mean    temp_var      ph_freq  ch_num  ...  log_ph_mean  \
# 56033   126.3000  2752.80000  3195.600000      15  ...     1.485452
# 31638     6.8095    12.93600    14.401000       1  ...     2.554925
# 5462    494.8200     0.08709     0.077984       3  ...     1.792847
# 60410     2.9503  3297.60000   431.080000      20  ...    -0.217857
#
#        log_ph_var  log_temp_mean  log_temp_var  log_ph_freq  neighs  w_neighs  \
# 56033   -0.846765       2.101403      3.439775     3.504552       0       0.0
# 31638   -1.261465       0.833115      1.111800     1.158393     748       0.0
# ...

# %%
df.sort_values(by=['temp_mean'])
# Out:
#        index              ch       pos          gene    ph_mean    ph_var  \
# 59773  11169  NW_022145594.1   6672069     LOC581667   0.029805  0.025286
# 3936   57143  NW_022145611.1  27961972             -   0.018516  0.027962
# 57215  43507  NW_022145598.1   2269895  LOC105443505   0.020339  0.045709
# 51139  14858  NW_022145607.1  25991899  LOC100892484   0.023359  0.036428
# 23471  43734  NW_022145598.1  29954595             -   0.027959  0.030025
# ...      ...             ...       ...           ...        ...       ...
# 59890    223  NW_022145594.1  19082021  LOC105437519   6.297800  0.049036
# 1749   58896  NW_022145612.1  53637511             -   0.323180  0.040406
# 56033  36890  NW_022145609.1  33060838  LOC100888699  30.581000  0.142310
# 35080   7073  NW_022145611.1  29386145     LOC588667  10.502000  0.043508
# 5462   28763  NW_022145613.1  17186308             -  62.065000  0.110530
#
#         temp_mean     temp_var      ph_freq  ch_num  ...  log_ph_mean  \
# ...

# %%
ph_mean:
    LOC580371 - gli3
    rest not in gene

# %%
ph_freq:
    LOC100888699 - RNA exonuclease 1 #second highest of them all! high in temp var and ph freq
    LOC100888006 - mucin-17 #highest of them all! high in temp var and ph freq
    LOC105444744 - pgap4
    non
    LOC575027 - fibrillin-1 # non of these in network

# %%
temp_mean:
    non
    LOC588667 - SPARC-related modular calcium-binding protein 1 #many neigh (0 weighted), high exp
    LOC100888699 - RNA exonuclease 1
    non
    LOC105437519 - uncharacterised

# %%
temp_var:
    LOC100888006 - mucin-17
    LOC100888699 - RNA exonuclease 1
    non
    non
    LOC105444744 - pgap4

# %%
#gli3 transcription factor highest in ph_mean, also high ph_freq, temp_var and temp_mean -->  high exp level, high # neigh (although weighted = 0), high snp count

# %%
#RNA exonuclease 1 highest in ph_freq, also high temp_mean, and temp_var, not in network

# %%
#noncoding highest in temp_mean

# %%
#mucin-17 highest in temp_var, also high in ph_freq, temp mean, not in network

# %%
where the “days” are ph_var_cat, ph_mean_cat, "temp_mean_cat”,”temp_var_cat”, "ph_freq_cat"

the “smoker” is blow or above

and “total bill” is snp_count

# %%
sns.set_theme(style="whitegrid")

tips = sns.load_dataset("tips")

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="Set3")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
I want a column: env_var with ph_mean,ph_freq etc., a column: below or above, a column: snp
# Out:
#   File "<ipython-input-38-63f80c4f2e15>", line 1
#     I want a column: env_var with ph_mean,ph_freq etc., a column: below or above, a column: snp
#       ^
# SyntaxError: invalid syntax

# %%
ndf
# Out:
#       ph_mean_cat ph_freq_cat temp_var_cat temp_mean_cat  snp_count
# 0           below       below        below         below        4.0
# 1           below       below        below         below        4.0
# 2           below       below        below         below        4.0
# 3           below       below        below         below        4.0
# 4           below       below        below         above        5.0
# ...           ...         ...          ...           ...        ...
# 11981       below       below        below         below        1.0
# 11982       below       below        below         below        1.0
# 11983       below       below        above         above        1.0
# 11984       below       above        below         below        1.0
# 11985       below       below        below         below        1.0
#
# [11986 rows x 5 columns]

# %%
phm=ndf[["ph_mean_cat","snp_count"]].copy()
phm["env_var"]="ph_mean_cat"
phm=phm.rename(columns={"ph_mean_cat": "bayenv"})

# %%
phf=ndf[["ph_freq_cat","snp_count"]].copy()
phf["env_var"]="ph_freq_cat"
phf=phf.rename(columns={"ph_freq_cat": "bayenv"})

# %%
tm=ndf[["temp_mean_cat","snp_count"]].copy()
tm["env_var"]="temp_mean_cat"
tm=tm.rename(columns={"temp_mean_cat": "bayenv"})

# %%
tv=ndf[["temp_var_cat","snp_count"]].copy()
tv["env_var"]="temp_var_cat"
tv=tv.rename(columns={"temp_var_cat": "bayenv"})

# %%
tv
# Out:
#       bayenv  snp_count       env_var
# 0      below        4.0  temp_var_cat
# 1      below        4.0  temp_var_cat
# 2      below        4.0  temp_var_cat
# 3      below        4.0  temp_var_cat
# 4      below        5.0  temp_var_cat
# ...      ...        ...           ...
# 11981  below        1.0  temp_var_cat
# 11982  below        1.0  temp_var_cat
# 11983  above        1.0  temp_var_cat
# 11984  below        1.0  temp_var_cat
# 11985  below        1.0  temp_var_cat
#
# [11986 rows x 3 columns]

# %%
result = pd.concat([phm,phf,tm,tv])

# %%
result.reset_index()
# Out:
#        index bayenv  snp_count       env_var
# 0          0  below        4.0   ph_mean_cat
# 1          1  below        4.0   ph_mean_cat
# 2          2  below        4.0   ph_mean_cat
# 3          3  below        4.0   ph_mean_cat
# 4          4  below        5.0   ph_mean_cat
# ...      ...    ...        ...           ...
# 47939  11981  below        1.0  temp_var_cat
# 47940  11982  below        1.0  temp_var_cat
# 47941  11983  above        1.0  temp_var_cat
# 47942  11984  below        1.0  temp_var_cat
# 47943  11985  below        1.0  temp_var_cat
#
# [47944 rows x 4 columns]

# %%
ax = sns.boxplot(x="bayenv", y="snp_count",data=result, palette="Set3")
